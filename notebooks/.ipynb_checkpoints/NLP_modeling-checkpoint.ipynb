# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS

# %%
nlp = spacy.load("en_core_web_sm")

# %%
sds_guest = pd.read_csv('../data/sds_guest.csv')

# %%
sds_guest
# Out:
#                                           episode_name  length_episode  \
# 0     Ruben Kogel on Self-Serve Analytics, R vs Pyt...              42
# 1     Machine Learning, Recommender Systems and the...              51
# 2     Defining the Data Problem, Data Science in Ma...              53
# 3     Data and Strategy, three Pillars of Research ...              60
# 4     Computer Forensics, Fraud Analytics and knowi...              63
# ..                                                 ...             ...
# 378                             Cloud Machine Learning              63
# 379   Taipy, the open-source Python application bui...              72
# 380         Pandas for Data Analysis and Visualization              69
# 381             Digital Analytics with Avinash Kaushik              88
# 382   The A.I. and Machine Learning Landscape, with...              94
#
#                                    context_episode  \
# 0                   Business Data Science Database
# ...

# %%
stopwords = list(STOP_WORDS)
