'https://www.superdatascience.com/podcast/sds-018-20-years-in-data-analytics-entrepreneurship-and-megatrends-in-data-with-jen-underwood',
'https://www.superdatascience.com/podcast/sds-019-government-work-revisiting-left-brainright-brain-and-artistic-thinking-with-ot-ratsaphong',
'https://www.superdatascience.com/podcast/sds-020-generation-z-insights-data-privacy-and-sql-and-database-design-with-ilya-eremenko',
'https://www.superdatascience.com/podcast/sds-021-applications-of-data-science-democratizing-ai-and-advice-with-sinan-ozdemir',
'https://www.superdatascience.com/podcast/sds-023-data-in-marketing-statistical-significance-and-management-and-career-advice-with-sam-flegal',
'https://www.superdatascience.com/podcast/sds-025-women-in-stem-bench-science-to-data-science-and-data-and-medical-ethics-with-kimberly-deas',
'https://www.superdatascience.com/podcast/sds-027-career-choice-disruptions-in-finance-and-application-stacks-with-aziz-mamatov',
'https://www.superdatascience.com/podcast/sds-029-ai-in-recruitment-machine-learning-and-where-machines-can-outperform-humans-with-ben-taylor',
'https://www.superdatascience.com/podcast/sds-031-ab-testing-kissmetrics-and-ways-to-a-better-lifestyle-with-david-tanaskovic',
'https://www.superdatascience.com/podcast/sds-033-building-a-personal-brand-in-data-science-with-senior-insights-manager-josh-coulson',
'https://www.superdatascience.com/podcast/sds-035-build-data-science-masters-degree-david-venturi',
'https://www.superdatascience.com/podcast/sds-037-develop-dream-data-science-career-experfy',
'https://www.superdatascience.com/podcast/sds-039-key-data-science-statistical-skills-get-hired-vsco',
'https://www.superdatascience.com/podcast/sds-041-inspiring-journey-totally-different-background-data-science',
'https://www.superdatascience.com/podcast/sds-043-solving-optimization-problem-custom-built-algorithm',
'https://www.superdatascience.com/podcast/sds-045-exclusive-interview-legendary-kaggle-competitions-eu-jin-lok',
'https://www.superdatascience.com/podcast/sds-047-expert-overview-deep-learning-models-supervised-unsupervised',
'https://www.superdatascience.com/podcast/sds-049-great-tips-building-successful-analytics-culture']

# %%
superdatascience = pd.DataFrame(columns = ['episode_name',
                              'length_episode',
                              'context_episode',
                              'guest_name',
                              'text_episode'])



def SuperDataScience(URL_LIST):
    
    driver = webdriver.Chrome()

    global superdatascience

    #List of variables
    episode = ""
    length = ""
    context = ""
    guest = ""
    text = ""

    for url in URL_LIST:
        driver.get(url)
        time.sleep(10)
    
        html_content = driver.page_source
        soup = BS(html_content, 'html.parser')
    
        topic_element = soup.find('h2')
        episode = topic_element.text.strip()
    
    
        p_element = soup.find('p', class_='read-time')
        length = p_element.text.strip()
     
        tag_element = soup.find('p', class_='tags')
        context = tag_element.text.strip()
      
    
        guest_element = soup.find('div', class_='information')
        guest = guest_element.text.strip()
      
        text_element = soup.find('div', {'class': 'content block-animation'})
        text = text_element.text.strip()
    
        superdatascience = superdatascience.append({'episode_name': episode, 
                                                'length_episode': length, 
                                                'context_episode' : context, 
                                                'guest_name': guest ,
                                                'text_episode': text}, ignore_index = True) 

       
    driver.close()

# %%
#SuperDataScience(url_list)

# %%
SuperDataScience(url_list_1_49)
# Out:
# /var/folders/s3/9_r9v9px7_v0q69b5zcbnmsm0000gn/T/ipykernel_72925/1106715672.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   superdatascience = superdatascience.append({'episode_name': episode,
# /var/folders/s3/9_r9v9px7_v0q69b5zcbnmsm0000gn/T/ipykernel_72925/1106715672.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   superdatascience = superdatascience.append({'episode_name': episode,
# /var/folders/s3/9_r9v9px7_v0q69b5zcbnmsm0000gn/T/ipykernel_72925/1106715672.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   superdatascience = superdatascience.append({'episode_name': episode,
# ...

# %%
superdatascience
# Out:
#                                          episode_name length_episode  \
# 0   SDS 001: Ruben Kogel on Self-Serve Analytics, ...     42 minutes
# 1   SDS 002: Machine Learning, Recommender Systems...     51 minutes
# 2   SDS 003: Defining the Data Problem, Data Scien...     53 minutes
# 3   SDS 004: Data and Strategy, three Pillars of R...     60 minutes
# 4   SDS 005: Computer Forensics, Fraud Analytics a...     63 minutes
# 5   SDS 006: Financial Modeling and Data Science, ...     53 minutes
# 6   SDS 007: Advanced Analytics, Dynamic Simulatio...     67 minutes
# 7   SDS 008: Data Science in Computer Games, learn...     62 minutes
# 8   SDS 009: Neuroscience, Machine Learning and Mo...     59 minutes
# 9   SDS 010: Model Validation, Data Exhaust and Or...     64 minutes
# 10  SDS 011: Learning resources, thinking like a D...     65 minutes
# 11  SDS 012: Online Learning, Tableau Insights and...     48 minutes
# 12  SDS 013: 95% Accuracy Models, Winning People O...     63 minutes
# ...

# %%
superdatascience

# %%
superdatascience.to_csv('sds1_49.csv')

# %%
superdatascience['text_episode'].loc[15]
# Out:
# "Kirill:\tThis is episode number 16, with Director at PricewaterhouseCoopers Richard Hopkins.(background music plays)Welcome to the SuperDataScience podcast. My name is Kirill Eremenko, data science coach and lifestyle entrepreneur. And each week we bring you inspiring people and ideas to help you build your successful career in data science. Thanks for being here today and now let’s make the complex simple.(background music plays)Hello and welcome to this episode of the SuperDataScience podcast. I'm super excited to bring you today my good friend and mentor, Richard Hopkins. Richard and I go way back. We met back in 2012, when we were both working at Deloitte, and we've had a hell of a ride since. We worked on this massive project for months and months and months where we were flying in and out of this remote location, and we really got to bond along the way. And in this episode, we share our experiences about two things. First of all, we talk about data and how Richard, being the d
# ...
